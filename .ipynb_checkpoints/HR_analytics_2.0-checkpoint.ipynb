# %% [markdown]
# # Employee Retention Analysis
# ----
# Employees are the life blood of the company. Therefore turnover is very costly to the company. I would like to analyze this hr data set to see how to retain employees
#
# First I start with importing the necessary programs and establish a file path to the proper data set.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib as matplot
import seaborn as sns
from sklearn import linear_model

# %matplotlib inline

file_path = ('human-resources-analytics/HR_comma_sep.csv')

# %%
pd.read_csv(file_path)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# 5                    0.41             0.50               2
# 6                    0.10             0.77               6
# 7                    0.92             0.85               5
# 8                    0.89             1.00               5
# 9                    0.42             0.53               2
# 10                   0.45             0.54               2
# 11                   0.11             0.81               6
# 12                   0.84             0.92               4
# 13                   0.41             0.55               2
# 14                   0.36             0.56               2
# 15                   0.38             0.54               2
# 16                   0.45             0.47               2
# 17                   0.78             0.99               4
# 18                   0.45             0.51               2
# 19                   0.76             0.89               5
# 20                   0.11             0.83               6
# 21                   0.38             0.55               2
# 22                   0.09             0.95               6
# 23                   0.46             0.57               2
# 24                   0.40             0.53               2
# 25                   0.89             0.92               5
# 26                   0.82             0.87               4
# 27                   0.40             0.49               2
# 28                   0.41             0.46               2
# 29                   0.38             0.50               2
# ...                   ...              ...             ...
# 14969                0.43             0.46               2
# 14970                0.78             0.93               4
# 14971                0.39             0.45               2
# 14972                0.11             0.97               6
# 14973                0.36             0.52               2
# 14974                0.36             0.54               2
# 14975                0.10             0.79               7
# 14976                0.40             0.47               2
# 14977                0.81             0.85               4
# 14978                0.40             0.47               2
# 14979                0.09             0.93               6
# 14980                0.76             0.89               5
# 14981                0.73             0.93               5
# 14982                0.38             0.49               2
# 14983                0.72             0.84               5
# 14984                0.40             0.56               2
# 14985                0.91             0.99               5
# 14986                0.85             0.85               4
# 14987                0.90             0.70               5
# 14988                0.46             0.55               2
# 14989                0.43             0.57               2
# 14990                0.89             0.88               5
# 14991                0.09             0.81               6
# 14992                0.40             0.48               2
# 14993                0.76             0.83               6
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# 2                       272                   4              0     1
# 3                       223                   5              0     1
# 4                       159                   3              0     1
# 5                       153                   3              0     1
# 6                       247                   4              0     1
# 7                       259                   5              0     1
# 8                       224                   5              0     1
# 9                       142                   3              0     1
# 10                      135                   3              0     1
# 11                      305                   4              0     1
# 12                      234                   5              0     1
# 13                      148                   3              0     1
# 14                      137                   3              0     1
# 15                      143                   3              0     1
# 16                      160                   3              0     1
# 17                      255                   6              0     1
# 18                      160                   3              1     1
# 19                      262                   5              0     1
# 20                      282                   4              0     1
# 21                      147                   3              0     1
# 22                      304                   4              0     1
# 23                      139                   3              0     1
# 24                      158                   3              0     1
# 25                      242                   5              0     1
# 26                      239                   5              0     1
# 27                      135                   3              0     1
# 28                      128                   3              0     1
# 29                      132                   3              0     1
# ...                     ...                 ...            ...   ...
# 14969                   157                   3              0     1
# 14970                   225                   5              0     1
# 14971                   140                   3              0     1
# 14972                   310                   4              0     1
# 14973                   143                   3              0     1
# 14974                   153                   3              0     1
# 14975                   310                   4              0     1
# 14976                   136                   3              0     1
# 14977                   251                   6              0     1
# 14978                   144                   3              0     1
# 14979                   296                   4              0     1
# 14980                   238                   5              0     1
# 14981                   162                   4              0     1
# 14982                   137                   3              0     1
# 14983                   257                   5              0     1
# 14984                   148                   3              0     1
# 14985                   254                   5              0     1
# 14986                   247                   6              0     1
# 14987                   206                   4              0     1
# 14988                   145                   3              0     1
# 14989                   159                   3              1     1
# 14990                   228                   5              1     1
# 14991                   257                   4              0     1
# 14992                   155                   3              0     1
# 14993                   293                   6              0     1
# 14994                   151                   3              0     1
# 14995                   160                   3              0     1
# 14996                   143                   3              0     1
# 14997                   280                   4              0     1
# 14998                   158                   3              0     1
#
#        promotion_last_5years       sales  salary
# 0                          0       sales     low
# 1                          0       sales  medium
# 2                          0       sales  medium
# 3                          0       sales     low
# 4                          0       sales     low
# 5                          0       sales     low
# 6                          0       sales     low
# 7                          0       sales     low
# 8                          0       sales     low
# 9                          0       sales     low
# 10                         0       sales     low
# 11                         0       sales     low
# 12                         0       sales     low
# 13                         0       sales     low
# 14                         0       sales     low
# 15                         0       sales     low
# 16                         0       sales     low
# 17                         0       sales     low
# 18                         1       sales     low
# 19                         0       sales     low
# 20                         0       sales     low
# 21                         0       sales     low
# 22                         0       sales     low
# 23                         0       sales     low
# 24                         0       sales     low
# 25                         0       sales     low
# 26                         0       sales     low
# 27                         0       sales     low
# 28                         0  accounting     low
# 29                         0  accounting     low
# ...                      ...         ...     ...
# 14969                      0       sales  medium
# 14970                      0       sales  medium
# 14971                      0       sales  medium
# 14972                      0  accounting  medium
# 14973                      0  accounting  medium
# 14974                      0  accounting  medium
# 14975                      0          hr  medium
# 14976                      0          hr  medium
# 14977                      0          hr  medium
# 14978                      0          hr  medium
# 14979                      0   technical  medium
# 14980                      0   technical    high
# 14981                      0   technical     low
# 14982                      0   technical  medium
# 14983                      0   technical  medium
# 14984                      0   technical  medium
# 14985                      0   technical  medium
# 14986                      0   technical     low
# 14987                      0   technical     low
# 14988                      0   technical     low
# 14989                      0   technical     low
# 14990                      0     support     low
# 14991                      0     support     low
# 14992                      0     support     low
# 14993                      0     support     low
# 14994                      0     support     low
# 14995                      0     support     low
# 14996                      0     support     low
# 14997                      0     support     low
# 14998                      0     support     low
#
# [14999 rows x 10 columns]

# %%
df = pd.read_csv(file_path)

# %% [markdown]
# The dateset had some confusion column names and even mispelled month, so I went ahead to rename some columns into simpler names.

# %%
df = df.rename(columns={'satisfaction_level': 'satisfaction', 
                        'number_project': 'project_count',
                        'average_montly_hours': 'average_monthly_hours',
                        'time_spend_company': 'years_at_company',
                        'sales' : 'department',
                        'left' : 'turnover'
                        })

# %%
df.describe()
# Out:
#        satisfaction  last_evaluation  project_count  average_monthly_hours  \
# count  14999.000000     14999.000000   14999.000000           14999.000000
# mean       0.612834         0.716102       3.803054             201.050337
# std        0.248631         0.171169       1.232592              49.943099
# min        0.090000         0.360000       2.000000              96.000000
# 25%        0.440000         0.560000       3.000000             156.000000
# 50%        0.640000         0.720000       4.000000             200.000000
# 75%        0.820000         0.870000       5.000000             245.000000
# max        1.000000         1.000000       7.000000             310.000000
#
#        years_at_company  Work_accident      turnover  promotion_last_5years
# count      14999.000000   14999.000000  14999.000000           14999.000000
# mean           3.498233       0.144610      0.238083               0.021268
# std            1.460136       0.351719      0.425924               0.144281
# min            2.000000       0.000000      0.000000               0.000000
# 25%            3.000000       0.000000      0.000000               0.000000
# 50%            3.000000       0.000000      0.000000               0.000000
# 75%            4.000000       0.000000      0.000000               0.000000
# max           10.000000       1.000000      1.000000               1.000000

# %% [markdown]
# Since I was investigating turnover rate I decided to see the how many people that worked for the company ultimately left.
#
# I divided the number of turnovers by the total number of employees in the dateset.

# %%
turnover_rate = df.turnover.value_counts() / len(df)
turnover_rate
# Out:
# 0    0.761917
# 1    0.238083
# Name: turnover, dtype: float64

# %% [markdown]
# The turnover rate is rather high at approximately 24%, almost the quarter of the workforce. Next I wanted to see if the high turnover came from a specific department within the company so I used df.groupby to find the total number of employee turnover grouped by departmen and divided that by the total number of employees, grouped by deparment to get the turnover rate in each department.

# %%
df.corr()
# Out:
#                        satisfaction  last_evaluation  project_count  \
# satisfaction               1.000000         0.105021      -0.142970
# last_evaluation            0.105021         1.000000       0.349333
# project_count             -0.142970         0.349333       1.000000
# average_monthly_hours     -0.020048         0.339742       0.417211
# years_at_company          -0.100866         0.131591       0.196786
# Work_accident              0.058697        -0.007104      -0.004741
# turnover                  -0.388375         0.006567       0.023787
# promotion_last_5years      0.025605        -0.008684      -0.006064
# department                 0.003153         0.007772       0.009268
# salary                     0.011754         0.013965       0.009672
#
#                        average_monthly_hours  years_at_company  Work_accident  \
# satisfaction                       -0.020048         -0.100866       0.058697
# last_evaluation                     0.339742          0.131591      -0.007104
# project_count                       0.417211          0.196786      -0.004741
# average_monthly_hours               1.000000          0.127755      -0.010143
# years_at_company                    0.127755          1.000000       0.002120
# Work_accident                      -0.010143          0.002120       1.000000
# turnover                            0.071287          0.144822      -0.154622
# promotion_last_5years              -0.003544          0.067433       0.039245
# department                          0.003913         -0.018010       0.003425
# salary                              0.007082         -0.003086      -0.002506
#
#                        turnover  promotion_last_5years  department    salary
# satisfaction          -0.388375               0.025605    0.003153  0.011754
# last_evaluation        0.006567              -0.008684    0.007772  0.013965
# project_count          0.023787              -0.006064    0.009268  0.009672
# average_monthly_hours  0.071287              -0.003544    0.003913  0.007082
# years_at_company       0.144822               0.067433   -0.018010 -0.003086
# Work_accident         -0.154622               0.039245    0.003425 -0.002506
# turnover               1.000000              -0.061788    0.032105 -0.001294
# promotion_last_5years -0.061788               1.000000   -0.027336 -0.001318
# department             0.032105              -0.027336    1.000000  0.000685
# salary                -0.001294              -0.001318    0.000685  1.000000

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(), square=True, annot=True, robust = True).set_title('HR Analysis Heatmap')

ax = plt.title

# %% [markdown]
# The headmap doesn't show any variables with very high correlation.
# There is a notable negative correlation between turnover and satisfaction to explore.
# The highest notable correlation is between project count and average monthly hours
# Since there was no high correlation I will analyze how turnover looks through notable variables.

# %%
ax = sns.countplot(y='department', data=df).set_title('Employee Count by Department')

# %%
ax = sns.countplot(y='department', hue='turnover', data=df).set_title('Employee Department Turnover Distribution')

# %% [markdown]
# Based on the graph the highest turnover is in the Sales, Technical, and Support departments but the high turnover in these cases may be due to the large number of employees that work in that department.

# %%
df['department'].value_counts()
df.groupby(['department']).sum()['turnover']

df.groupby(['department']).sum()['turnover']/df['department'].value_counts()
# Out:
# IT             0.222494
# RandD          0.153748
# accounting     0.265971
# hr             0.290934
# management     0.144444
# marketing      0.236597
# product_mng    0.219512
# sales          0.244928
# support        0.248991
# technical      0.256250
# dtype: float64

# %% [markdown]
# Calcualting turnover in each department as a percentage provides a better understanding of turnover.
# 1. The majority of departments are losing 20% or more of there employees.
# 2. Human resources suffers the most.
# 3. Management department and R&D suffered the least amount of turnover.

# %% [markdown]
# # Turnover Based on Salary.

# %%
plt.subplots(figsize=(5, 5)) 
ax = sns.countplot(x='salary', hue='turnover', data=df,).set_title('Employee Salary Turnover Distribution')

# %%
ax = sns.countplot(y='department', hue='salary', data=df).set_title('Employee Salary by Department')

# %% [markdown]
# Conclusions that I drew from organizing the data based on salary is that:
# 1. The majority of people who left had either medium or low salary.
# 2. Management has the only department where more workers recieved high salaries than low salaries.

# %% [markdown]
# # Turnover Based on Satisfaction

# %%
x = df.loc[(df['turnover'] == 0), 'satisfaction']
ax = sns.distplot(x, bins=20, hist=True, kde=True, color='b')

y = df.loc[(df['turnover'] == 1), 'satisfaction']
ax = sns.distplot(y, bins=20, hist=True, kde=True, color='r')

# %% [markdown]
# # Turnover Based on Evaluation

# %%
x = df.loc[(df['turnover'] == 0),'last_evaluation']
ax = sns.distplot(x, bins=30, hist=True, kde=True, color='b')

y = df.loc[(df['turnover'] == 1),'last_evaluation']
ax = sns.distplot(y, bins=30, hist=True, kde=True, color='r')

# %% [markdown]
# # Turnover Based on Project Count

# %%
x = df.loc[(df['turnover'] == 0), 'project_count']
ax = sns.distplot(x, bins=10, hist=True, kde=True, color='b')

y = df.loc[(df['turnover'] == 1), 'project_count']
ax = sns.distplot(y, bins=10, hist=True, kde=True, color='r')

# %% [markdown]
# # Turnover Based on Average Monthly Hours

# %%
x = df.loc[(df['turnover'] == 0), 'average_monthly_hours']
ax = sns.distplot(x, bins=20, hist=True, kde=True, color='b')

x = df.loc[(df['turnover'] == 1), 'average_monthly_hours']
ax = sns.distplot(x, bins=20, hist=True, kde=True, color='r')

# %% [markdown]
# # Turnover Based on Project Count

# %%
x = df.loc[(df['turnover'] == 0), 'project_count']
ax = sns.distplot(x, bins=10, hist=True, kde=True, color='b')

x = df.loc[(df['turnover'] == 1), 'project_count']
ax = sns.distplot(x, bins=10, hist=True, kde=True, color='r')

# %% [markdown]
# # Turnover Based on Years at Company

# %%
x = df.loc[(df['turnover'] == 0), 'years_at_company']
ax = sns.distplot(x, bins=8, hist=True, kde=True, color='b')

x = df.loc[(df['turnover'] == 1), 'years_at_company']
ax = sns.distplot(x, bins=8, hist=True, kde=True, color='r')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, precision_score, recall_score, confusion_matrix, precision_recall_curve
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
hr_features = df[['satisfaction',
   'last_evaluation',
   'project_count',
   'average_monthly_hours',
   'years_at_company',
   'Work_accident',
   'promotion_last_5years',
    'department',
    'salary'
   ]]

df["department"] = df["department"].astype('category').cat.codes
df["salary"] = df["salary"].astype('category').cat.codes

hr_target = df[['turnover']]

x = hr_features
y = hr_target

x = df.drop('turnover', axis=1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 4)

from sklearn.preprocessing import StandardScaler
sc_x=StandardScaler()
x_train=sc_x.fit_transform(x_train)
x_test=sc_x.transform(x_test)

# %%
lr_model = LogisticRegression()
lr_model.fit(x_train, y_train.values.ravel())

predict = lr_model.predict(x_test)
accuracy_score(y_test, predict)
# Out:
# 0.7698666666666667

# %%
trees = tree.DecisionTreeClassifier()
trees.fit(x_train, y_train)
prediction_tree = trees.predict(x_test)
accuracy_score(y_test, prediction_tree)
# Out:
# 0.97786666666666666

# %%
from sklearn.datasets import load_iris

iris = load_iris()
trees = trees.fit(iris.data, iris.target)
tree.export_graphviz(trees,
    out_file='tree.dot')

# %%
forest = RandomForestClassifier()
forest.fit(x_train, y_train.values.ravel())
predict_forest = forest.predict(x_test)
accuracy_score(y_test, predict_forest)
# Out:
# 0.98853333333333337

# %%
k = KNeighborsClassifier()
k.fit(x_train, y_train.values.ravel())
predict_k = k.predict(x_test)
accuracy_score(y_test, predict_k)
# Out:
# 0.95626666666666671

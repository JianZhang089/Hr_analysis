# %% [markdown]
# # Employee Retention Analysis
# ----
# Employee turnover is a challenge many companies face. Employee's leave for multiple reasons and in analyzing employee turnover through multiple variables to find outwhat makes people leave a job.
#
# First I start with importing the necessary programs and establish a file path to the proper data set.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib as matplot
import seaborn as sns
from sklearn import linear_model

# %matplotlib inline

file_path = ('human-resources-analytics/HR_comma_sep.csv')

# %%
##pd.read_csv(file_path) to see if the data set was imported properly.
df = pd.read_csv(file_path)

# %% [markdown]
# I went ahead to rename some columns into more readable names.

# %%
df = df.rename(columns={'satisfaction_level': 'satisfaction', 
                        'number_project': 'project_count',
                        'average_montly_hours': 'average_monthly_hours',
                        'time_spend_company': 'years_at_company',
                        'sales' : 'department',
                        'left' : 'turnover'
                        })

# %% [markdown]
# # Overview

# %% [markdown]
# First I wanted to see what what variables I would be working with.

# %%
df.shape
# Out:
# (14999, 10)

# %%
df.dtypes
# Out:
# satisfaction             float64
# last_evaluation          float64
# project_count              int64
# average_monthly_hours      int64
# years_at_company           int64
# Work_accident              int64
# turnover                   int64
# promotion_last_5years      int64
# department                object
# salary                    object
# dtype: object

# %% [markdown]
# Based on the rows and columns the data covers 14999 employees in 10 different catagories.

# %%
df.describe()
# Out:
#        satisfaction  last_evaluation  project_count  average_monthly_hours  \
# count  14999.000000     14999.000000   14999.000000           14999.000000
# mean       0.612834         0.716102       3.803054             201.050337
# std        0.248631         0.171169       1.232592              49.943099
# min        0.090000         0.360000       2.000000              96.000000
# 25%        0.440000         0.560000       3.000000             156.000000
# 50%        0.640000         0.720000       4.000000             200.000000
# 75%        0.820000         0.870000       5.000000             245.000000
# max        1.000000         1.000000       7.000000             310.000000
#
#        years_at_company  Work_accident      turnover  promotion_last_5years
# count      14999.000000   14999.000000  14999.000000           14999.000000
# mean           3.498233       0.144610      0.238083               0.021268
# std            1.460136       0.351719      0.425924               0.144281
# min            2.000000       0.000000      0.000000               0.000000
# 25%            3.000000       0.000000      0.000000               0.000000
# 50%            3.000000       0.000000      0.000000               0.000000
# 75%            4.000000       0.000000      0.000000               0.000000
# max           10.000000       1.000000      1.000000               1.000000

# %% [markdown]
# Since I was investigating turnover rate I decided to see the how many people that worked for the company left.
# I divided the number of employees that left by the total number of employees in the dateset.

# %%
turnover_rate = df.turnover.value_counts() / len(df)
turnover_rate
# Out:
# 0    0.761917
# 1    0.238083
# Name: turnover, dtype: float64

# %% [markdown]
# The turnover rate is rather high at approximately 24%, almost the quarter of the workforce. Next I wanted to see if the high turnover came from a specific department within the company so I used df.groupby to find the total number of employee turnover grouped by departmen and divided that by the total number of employees, grouped by deparment to get the turnover rate in each department.

# %% [markdown]
# Next I wanted to find out how all the variables correlated with each other and see specifically if turnover has any correlation with any of the other variables.

# %%
df.corr()
# Out:
#                        satisfaction  last_evaluation  project_count  \
# satisfaction               1.000000         0.105021      -0.142970
# last_evaluation            0.105021         1.000000       0.349333
# project_count             -0.142970         0.349333       1.000000
# average_monthly_hours     -0.020048         0.339742       0.417211
# years_at_company          -0.100866         0.131591       0.196786
# Work_accident              0.058697        -0.007104      -0.004741
# turnover                  -0.388375         0.006567       0.023787
# promotion_last_5years      0.025605        -0.008684      -0.006064
#
#                        average_monthly_hours  years_at_company  Work_accident  \
# satisfaction                       -0.020048         -0.100866       0.058697
# last_evaluation                     0.339742          0.131591      -0.007104
# project_count                       0.417211          0.196786      -0.004741
# average_monthly_hours               1.000000          0.127755      -0.010143
# years_at_company                    0.127755          1.000000       0.002120
# Work_accident                      -0.010143          0.002120       1.000000
# turnover                            0.071287          0.144822      -0.154622
# promotion_last_5years              -0.003544          0.067433       0.039245
#
#                        turnover  promotion_last_5years
# satisfaction          -0.388375               0.025605
# last_evaluation        0.006567              -0.008684
# project_count          0.023787              -0.006064
# average_monthly_hours  0.071287              -0.003544
# years_at_company       0.144822               0.067433
# Work_accident         -0.154622               0.039245
# turnover               1.000000              -0.061788
# promotion_last_5years -0.061788               1.000000

# %%
plt.figure(figsize=(12,12))
sns.set(font_scale=1.2)
ax = sns.heatmap(df.corr(), square=True, annot=True, robust = True).set_title('HR Analysis Heatmap')

# %% [markdown]
# The headmap doesn't show any variables with very high correlation.
# The first thing that jumps out to me is a notable negative correlation between turnover and satisfaction to explore.
# The highest notable correlation is between project count and average monthly hours
# Since there was no high correlation I will analyze how turnover looks through notable variables.

# %%
ax = sns.countplot(y='department', data=df).set_title('Employee Count by Department')

# %%
df['department'].value_counts()
# Out:
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: department, dtype: int64

# %%
ax = sns.countplot(y='department', hue='turnover', data=df).set_title('Employee Department Turnover Distribution')

# %% [markdown]
# Based on the graph the highest turnover is in the Sales, Technical, and Support departments but  the high turnover in these cases may be due to these departments having the largest number of employees.

# %%
df['department'].value_counts()
df.groupby(['department']).sum()['turnover']

df.groupby(['department']).sum()['turnover']/df['department'].value_counts()
# Out:
# IT             0.222494
# RandD          0.153748
# accounting     0.265971
# hr             0.290934
# management     0.144444
# marketing      0.236597
# product_mng    0.219512
# sales          0.244928
# support        0.248991
# technical      0.256250
# dtype: float64

# %% [markdown]
# Calcualting turnover in each department as a percentage provides a better understanding of turnover.
# 1. The majority of departments are losing 20% or more of there employees.
# 2. Human resources suffers the most.
# 3. Management department and R&D suffered the least amount of turnover.

# %% [markdown]
# # Turnover Based on Salary.

# %%
plt.subplots(figsize=(5, 5)) 
ax = sns.countplot(x='salary', hue='turnover', data=df,).set_title('Employee Salary Turnover Distribution')

# %%
ax = sns.countplot(y='department', hue='salary', data=df).set_title('Employee Salary by Department')

# %% [markdown]
# Conclusions that I drew from organizing the data based on salary is that:
# 1. The majority of people who left had either medium or low salary.
# 2. Across departments low and medium wage workers disproportionately outnumber high wage employees.
#     Will require data with a more thorough breakdown of employee positions to eliminate bias.
# 3. Management has the only department where more workers recieved high salaries than low salaries.

# %% [markdown]
# # Turnover Based on Satisfaction

# %%
x = df.loc[(df['turnover'] == 0), 'satisfaction']
ax = sns.distplot(x, bins=20, hist=True, kde=True, color='b', label='stay')

y = df.loc[(df['turnover'] == 1), 'satisfaction']
ax = sns.distplot(y, bins=10, hist=True, kde=True, color='r', label='leave')

# %% [markdown]
# Employees with mid to high levels of satisfaction tend to stay with the company.
# Naturally employees who were extremely unsatisfied at their comapany left but interestingly employee statisfaction levels at distinct points of high, mid, and low also left the company.

# %% [markdown]
# # Turnover Based on Evaluation

# %%
x = df.loc[(df['turnover'] == 0),'last_evaluation']
ax = sns.distplot(x, bins=30, hist=True, kde=True, color='b', label='stay')

y = df.loc[(df['turnover'] == 1),'last_evaluation']
ax = sns.distplot(y, bins=30, hist=True, kde=True, color='r', label='leave')

# %% [markdown]
# Employees with either extremely high or extremely low evaluations tend to leave the company.

# %% [markdown]
# # Turnover Based on Project Count

# %%
x = df.loc[(df['turnover'] == 0), 'project_count']
ax = sns.distplot(x, bins=10, hist=True, kde=True, color='b', label='stay')

y = df.loc[(df['turnover'] == 1), 'project_count']
ax = sns.distplot(y, bins=10, hist=True, kde=True, color='r', label='leave')

# %% [markdown]
# Employees that stay with the company handled around 3-5 projects. Employees with more or less projects tend to leave.

# %% [markdown]
# # Turnover Based on Average Monthly Hours

# %%
x = df.loc[(df['turnover'] == 0), 'average_monthly_hours']
ax = sns.distplot(x, bins=20, hist=True, kde=True, color='b', label='stay')

x = df.loc[(df['turnover'] == 1), 'average_monthly_hours']
ax = sns.distplot(x, bins=20, hist=True, kde=True, color='r', label='leave')

# %% [markdown]
# Employees who work too many or to little tend to leave.

# %% [markdown]
# # Turnover Based on Years at Company

# %%
x = df.loc[(df['turnover'] == 0), 'years_at_company']
ax = sns.distplot(x, bins=8, hist=True, kde=True, color='b', label='stay')

x = df.loc[(df['turnover'] == 1), 'years_at_company']
ax = sns.distplot(x, bins=8, hist=True, kde=True, color='r', label='leave')

# %% [markdown]
# Most employees leave withing working 3 to 6 years with the company.

# %% [markdown]
# # Machine Learning

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, precision_score, recall_score, confusion_matrix, precision_recall_curve
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
hr_features = df[['satisfaction',
   'last_evaluation',
   'project_count',
   'average_monthly_hours',
   'years_at_company',
   'Work_accident',
   'promotion_last_5years',
    'department',
    'salary'
   ]]

df["department"] = df["department"].astype('category').cat.codes
df["salary"] = df["salary"].astype('category').cat.codes

hr_target = df[['turnover']]

x = hr_features
y = hr_target

x = df.drop('turnover', axis=1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 4)

from sklearn.preprocessing import StandardScaler
sc_x=StandardScaler()
x_train=sc_x.fit_transform(x_train)
x_test=sc_x.transform(x_test)

# %%
lr_model = LogisticRegression()
lr_model.fit(x_train, y_train.values.ravel())

predict = lr_model.predict(x_test)
accuracy_score(y_test, predict)
# Out:
# 0.7698666666666667

# %%
print(confusion_matrix(y_test, predict))
print('\n')
print(classification_report(y_test, predict))
# Out:
# [[2661  201]
#  [ 662  226]]
#
#
#              precision    recall  f1-score   support
#
#           0       0.80      0.93      0.86      2862
#           1       0.53      0.25      0.34       888
#
# avg / total       0.74      0.77      0.74      3750

# %%
k = KNeighborsClassifier()
k.fit(x_train, y_train.values.ravel())
predict_k = k.predict(x_test)
accuracy_score(y_test, predict_k)
# Out:
# 0.95626666666666671

# %%
print(confusion_matrix(y_test, predict_k))
print('\n')
print(classification_report(y_test, predict_k))
# Out:
# [[2773   89]
#  [  75  813]]
#
#
#              precision    recall  f1-score   support
#
#           0       0.97      0.97      0.97      2862
#           1       0.90      0.92      0.91       888
#
# avg / total       0.96      0.96      0.96      3750

# %%
trees = tree.DecisionTreeClassifier()
trees.fit(x_train, y_train)
prediction_tree = trees.predict(x_test)
accuracy_score(y_test, prediction_tree)
# Out:
# 0.97760000000000002

# %%
print(confusion_matrix(y_test, prediction_tree))
print('\n')
print(classification_report(y_test, prediction_tree))
# Out:
# [[2812   50]
#  [  34  854]]
#
#
#              precision    recall  f1-score   support
#
#           0       0.99      0.98      0.99      2862
#           1       0.94      0.96      0.95       888
#
# avg / total       0.98      0.98      0.98      3750

# %%
importances = trees.feature_importances_
feat_names = df.drop(['turnover'],axis=1).columns


indices = np.argsort(importances)[::-1]
plt.figure(figsize=(12,6))
plt.title("Feature Importances by DecisionTreeClassifier")
plt.bar(range(len(indices)), importances[indices], color='lightgreen',  align="center")
plt.step(range(len(indices)), np.cumsum(importances[indices]), where='mid', label='Cumulative')
plt.xticks(range(len(indices)), feat_names[indices], rotation='vertical',fontsize=14)
plt.xlim([-1, len(indices)])
# Out:
# (-1, 9)

# %% [markdown]
# Top 5 Features (Decision Tree)
# 1. Satisfaction
# 2. Last Evaluation
# 3. Years at Company
# 4. Project Count
# 5. Average Monthly Hours

# %%
forest = RandomForestClassifier(n_estimators=1000)
forest.fit(x_train, y_train.values.ravel())
predict_forest = forest.predict(x_test)
accuracy_score(y_test, predict_forest)
# Out:
# 0.99199999999999999

# %%
print(confusion_matrix(y_test, predict_forest))
print('\n')
print(classification_report(y_test, predict_forest))
# Out:
# [[2860    2]
#  [  28  860]]
#
#
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      2862
#           1       1.00      0.97      0.98       888
#
# avg / total       0.99      0.99      0.99      3750

# %%
importances = forest.feature_importances_
feat_names = df.drop(['turnover'],axis=1).columns


indices = np.argsort(importances)[::-1]
plt.figure(figsize=(12,6))
plt.title("Feature importances by RandomForestClassifier")
plt.bar(range(len(indices)), importances[indices], color='red',  align="center")
plt.step(range(len(indices)), np.cumsum(importances[indices]), where='mid', label='Cumulative')
plt.xticks(range(len(indices)), feat_names[indices], rotation='vertical',fontsize=14)
plt.xlim([-1, len(indices)])
# Out:
# (-1, 9)

# %% [markdown]
# Top 5 Features (Random Forest)
# 1. Satisfaction
# 2. Years at Company
# 3. Project Count
# 4. Average Hours Worked
# 5. Last Evaluation

# %% [markdown]
# # Conclusions

# %% [markdown]
# Satisfaction in working for company plays the biggest factor in determining whether they stay or leave at the company. People left the company when they were on the lower end of satisfaction but also in the mid and high ends but not in between. We can assume people at the low end leave because they do not feel they fit in with the company. People in the middle are on the fence, in that they are fine with the company but are willing to leave for aother job they percieve to be better. While the ones with high satisfaction also leave but more employees with high satiscation tend to stay than leave.
#
# Project Count, Average Hours Worked, and Last Evaluation had a turnover distribution of an inverted bell curve. This indicates that employees either getting poor performace and not enough projects or hours, or they are employees that are performing very well that they may leave because they can do better somewhere else, or they are being overworked my the project load and long hours.
#
# Years at company, evaluations, the number of projects, and hours worked play varying levels of importance based on the two classifiers I ran. Years at company was within at least the top 3 of both classifiers and when looking at the distribution 3 years is when most people leave the company and where the turnover begins. Also in general most of the employees don't stick around for more than 6 years. This can be influenced by the lack of promotion in the company in the last 5 years. It wasn't a feature I used in my analysis but it is one that can speak for itself

# %%
df['promotion_last_5years'].value_counts()
# Out:
# 0    14680
# 1      319
# Name: promotion_last_5years, dtype: int64

# %%
df['promotion_last_5years'].value_counts()/len(df)
# Out:
# 0    0.978732
# 1    0.021268
# Name: promotion_last_5years, dtype: float64

# %% [markdown]
# Of all the employees in this large data set only around 2% of employees got promoted within the last 5 years which is something I couldn't express in the data but this plays a factor in employees leaving the company after 3 years.

# %% [markdown]
# So we can break down reasons for leaving into a few factors:
# Employees believing they can do better or get a better job at another company
# Leaving due to poor performance or satisfaction with the job.
# Employees either being overworked or not working enough.
# American business practices has lead to more people compelled to migrate jobs as common practice for advancement.

# %% [markdown]
# # Room for Improvement

# %% [markdown]
# Since satisfaction is the biggest reason employees leave I want to explore what features effect employee satisfaction. I can run that with this data set switching out turnover for satisfaction. I could run various models on the relationship between the hours worked at the company, the number of projects, and evaluations to get a better picture of overwork and underwork.
# I still don't know enough machine learning to do more than the train test split to train my data.

# %%
hr_features = df[['turnover',
   'last_evaluation',
   'project_count',
   'average_monthly_hours',
   'years_at_company',
   'Work_accident',
   'promotion_last_5years',
    'department',
    'salary'
   ]]

df["department"] = df["department"].astype('category').cat.codes
df["salary"] = df["salary"].astype('category').cat.codes

hr_target = df[['satisfaction']]

x = hr1_features
y = hr1_target

x = df.drop('satisfaction', axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-5c52f9414a6b> in <module>()
#      15 hr_target = df[['satisfaction']]
#      16
# ---> 17 x = hr1_features
#      18 y = hr1_target
#      19
#
# NameError: name 'hr1_features' is not defined

# %%
trees.fit(x_train, y_train)
prediction_tree = trees.predict(x_test)
accuracy_score(y_test, prediction_tree)

# %%
importances = trees.feature_importances_
feat_names = df.drop(['satisfaction'],axis=1).columns


indices = np.argsort(importances)[::-1]
plt.figure(figsize=(12,6))
plt.title("Feature importances by DecisionTreeClassifier")
plt.bar(range(len(indices)), importances[indices], color='lightgreen',  align="center")
plt.step(range(len(indices)), np.cumsum(importances[indices]), where='mid', label='Cumulative')
plt.xticks(range(len(indices)), feat_names[indices], rotation='vertical',fontsize=14)
plt.xlim([-1, len(indices)])

# %%
forest = RandomForestClassifier(n_estimators=1000)
forest.fit(x_train, y_train.values.ravel())
predict_forest = forest.predict(x_test)
accuracy_score(y_test, predict_forest)

# %%
importances = forest.feature_importances_
feat_names = df.drop(['satisfaction'],axis=1).columns


indices = np.argsort(importances)[::-1]
plt.figure(figsize=(12,6))
plt.title("Feature importances by randomTreeClassifier")
plt.bar(range(len(indices)), importances[indices], color='lightgreen',  align="center")
plt.step(range(len(indices)), np.cumsum(importances[indices]), where='mid', label='Cumulative')
plt.xticks(range(len(indices)), feat_names[indices], rotation='vertical',fontsize=14)
plt.xlim([-1, len(indices)])
